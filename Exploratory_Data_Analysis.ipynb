# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as mp
import numpy as np

# %%
df=pd.read_csv('iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
x_axis=df.index
y_axis=df['petal.length']
sb.scatterplot(x=x_axis, y=y_axis, hue=df['variety'])
# Out:
# <Axes: ylabel='petal.length'>

# %%
sb.stripplot(x=df['variety'],y=df['petal.length'])
# Out:
# C:\Users\lkmah\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lkmah\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='variety', ylabel='petal.length'>

# %%
sb.displot(df['petal.length'])
# Out:
# C:\Users\lkmah\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
mp.hist(df['petal.length'])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
mp.boxplot(x=df['petal.length'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14f688d98d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14f68991890>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14f668dded0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14f68992850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14f68993150>],
#  'means': []}

# %%
sb.boxplot(x=df['petal.length'])
# Out:
# <Axes: xlabel='petal.length'>

# %%
sb.countplot(x=df['variety'])
# Out:
# <Axes: xlabel='variety', ylabel='count'>

# %%
a=['SETOSA','VERSICOLOR','VIRGINIA']
mp.pie(df['variety'].value_counts(),labels=a)
# Out:
# ([<matplotlib.patches.Wedge at 0x14f68be4d10>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, 'SETOSA'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'VERSICOLOR'),
#   Text(0.5500001486524352, -0.9526278583383436, 'VIRGINIA')])

# %%
df1=pd.read_csv('titanic.csv')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sb.scatterplot(x=df1['Fare'], y=df1['Age'])
mp.title('Bivariate Analysis')
# Out:
# Text(0.5, 1.0, 'Bivariate Analysis')

# %%
df1[['Fare','Age']].corr()
# Out:
#           Fare       Age
# Fare  1.000000  0.096067
# Age   0.096067  1.000000

# %%
sb.heatmap(df1[['Fare','Age']].corr())
# Out:
# <Axes: >

# %%
sr=df1[['Pclass','Survived']].groupby('Pclass').sum()

# %%
sr
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
sb.barplot(x=sr.index, y=sr['Survived'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sb.boxplot(x=df1['Survived'], y=df1['Age'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sb.barplot(x=df1['Sex'], y=df1['Age'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
x=pd.Series([1,2,3,6,7,8,150])
mean=x.mean()
std=x.std()
z=abs((x-mean)/std)
median=np.median(x)
z
# Out:
# 0    0.441104
# 1    0.422941
# 2    0.404778
# 3    0.350288
# 4    0.332125
# 5    0.313962
# 6    2.265198
# dtype: float64

# %%
olr=x[z<=1.5]
olr
# Out:
# 0    1
# 1    2
# 2    3
# 3    6
# 4    7
# 5    8
# dtype: int64

# %%
x=pd.Series([1,2,3,6,7,8,150])
mean=x.mean()
std=x.std()
z=abs((x-mean)/std)
median=np.median(x)
median
# Out:
# 6.0

# %%
x[z>1.5]=median
x
# Out:
# 0    1
# 1    2
# 2    3
# 3    6
# 4    7
# 5    8
# 6    6
# dtype: int64

# %%
df1['Sex'].replace({'male':1, 'female':0},inplace=True)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
f= df1['Sex'].value_counts()/len(df1['Sex'])
f
# Out:
# Sex
# 1    0.647587
# 0    0.352413
# Name: count, dtype: float64

# %%
df1['Sex'].replace({'male':f[1], 'female':f[0]},inplace=True)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df1=pd.read_csv('titanic.csv')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
f= df1['Sex'].value_counts()/len(df1['Sex'])
f
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: count, dtype: float64

# %%
df1['Sex'].replace({'male':f['male'], 'female':f['female']},inplace=True)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name       Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  0.647587  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  0.352413  38.0      1
# 2                               Heikkinen, Miss. Laina  0.352413  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  0.352413  35.0      1
# 4                             Allen, Mr. William Henry  0.647587  35.0      0
# ...
